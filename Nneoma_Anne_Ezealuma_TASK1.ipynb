# %% [markdown]
# ## A
# ## My Grocery List

# %% [markdown]
# ## No.1

# %%
Grocery_list = ["Pasta", "Plantain", "Potatoe", "Vegetables", "Noodles"]

# %%
print(Grocery_list)
# Out:
# ['Pasta', 'Plantain', 'Potatoe', 'Vegetables', 'Noodles']

# %%
type(Grocery_list)
# Out:
# list

# %% [markdown]
# ## No.2

# %%
#Grocery list dictionary is saved as Groceryy_list_D

Groceryy_list_D = {"Pasta": "₦400", "Plantain": "₦900", "Potatoe": "₦700", "Vegetables": "₦300", "Noodles": "₦600" }

# %%
print(Groceryy_list_D)
# Out:
# {'Pasta': '₦400', 'Plantain': '₦900', 'Potatoe': '₦700', 'Vegetables': '₦300', 'Noodles': '₦600'}

# %%
type(Groceryy_list_D)
# Out:
# dict

# %% [markdown]
# ## No.3

# %%
print(Grocery_list)
# Out:
# ['Pasta', 'Plantain', 'Potatoe', 'Vegetables', 'Noodles']

# %%
first_Grocery = Grocery_list[0]

print(first_Grocery)
# Out:
# Pasta

# %%
Last_Grocery = Grocery_list[-1]

print(Last_Grocery)
# Out:
# Noodles

# %% [markdown]
# ## No.4

# %%
Groceryy_list_D["Plantain"]
# Out:
# '₦900'

# %%
plantain = Groceryy_list_D["Plantain"]

print(f"The price of the most expensive item on my dictionary is {plantain}")
# Out:
# The price of the most expensive item on my dictionary is ₦900

# %% [markdown]
# ## No.5

# %%
print(Grocery_list)
# Out:
# ['Pasta', 'Plantain', 'Potatoe', 'Vegetables', 'Noodles']

# %%
Grocery_list.append("Tomatoes")

# %%
Grocery_list.append("Onion")

# %%
print(Grocery_list)
# Out:
# ['Pasta', 'Plantain', 'Potatoe', 'Vegetables', 'Noodles', 'Tomatoes', 'Onion']

# %% [markdown]
# ## No.6

# %%
print(Groceryy_list_D)
# Out:
# {'Pasta': '₦400', 'Plantain': '₦900', 'Potatoe': '₦700', 'Vegetables': '₦300', 'Noodles': '₦600'}

# %%
Groceryy_list_D.values()
# Out:
# dict_values(['₦400', '₦900', '₦700', '₦300', '₦600'])

# %%
#Since the naira sign was identified as a string by python, I converted the values to integers so I can be able to use the sum operator on it

dict_values = [400,900,700,300,600]

# %%
Total = sum(dict_values)

# %%
print(Total)
# Out:
# 2900

# %%
print(f"The total cost of all the items is ₦{Total}")
# Out:
# The total cost of all the items is ₦2900

# %% [markdown]
# ## No.7

# %%
Grocery_list_tupule = ("Pasta", "Noodles", "Plantain")

# %%
print(Grocery_list_tupule)
# Out:
# ('Pasta', 'Noodles', 'Plantain')

# %% [markdown]
# ## No.8

# %%
print(Grocery_list)
# Out:
# ['Pasta', 'Plantain', 'Potatoe', 'Vegetables', 'Noodles', 'Tomatoes', 'Onion']

# %%
Grocery_list.sort()

# %%
print(Grocery_list)
# Out:
# ['Noodles', 'Onion', 'Pasta', 'Plantain', 'Potatoe', 'Tomatoes', 'Vegetables']

# %%
Arranged_list = sorted(Grocery_list)

# %%
print(Arranged_list)
# Out:
# ['Noodles', 'Onion', 'Pasta', 'Plantain', 'Potatoe', 'Tomatoes', 'Vegetables']

# %% [markdown]
# # B

# %% [markdown]
# ## Student Information System

# %% [markdown]
# ## No.1

# %%
Name = "Ottih Ifunanya"

# %%
print(Name)
# Out:
# Ottih Ifunanya

# %%
Age = 19

# %%
print(Age)
# Out:
# 19

# %%
GPA = 4.10

# %%
print(GPA)
# Out:
# 4.1

# %%
x = GPA

Pass = x > 3.5
Fail = x < 3.5

# %%
GPA > 3.5
# Out:
# True

# %%
GPA < 3.5
# Out:
# False

# %% [markdown]
# ## No.2

# %%
#Using the f'string

print(f"{Name} is a student of our school. She is {Age} years old and she has maintained a sound GPA of {GPA}")
# Out:
# Ottih Ifunanya is a student of our school. She is 19 years old and she has maintained a sound GPA of 4.1

# %% [markdown]
# ## No.3

# %%
Compulsary_Subjects = ["Mathematics", "GIS and Remote Sensing", "Photogeology", "Geochemistry", "Marine Geology"]

# %%
print (Compulsary_Subjects[1])

print  (Compulsary_Subjects[3])
# Out:
# GIS and Remote Sensing
# Geochemistry

# %% [markdown]
# ## No.4

# %%
Students_Hobbies = ("Hiking", "Cooking", "Painting")

# %%
print(Students_Hobbies[2])
# Out:
# Painting

# %% [markdown]
# ## No.5

# %%
Students_Details = {"Name":"Ottih Ifunanya", "Age":19, "GPA":4.1, "Passed":True, "Subjects":["Mathematics", "GIS and Remote Sensing", "Photogeology", "Geochemistry", "Marine Geology"]}

# %%
print(Students_Details)
# Out:
# {'Name': 'Ottih Ifunanya', 'Age': 19, 'GPA': 4.1, 'Passed': True, 'Subjects': ['Mathematics', 'GIS and Remote Sensing', 'Photogeology', 'Geochemistry', 'Marine Geology']}

# %% [markdown]
# ## No.6

# %%
Students_Test_Scores = [78, 80, 92, 56, 85]

# %%
average = sum(Students_Test_Scores) / len(Students_Test_Scores)

print(average)
# Out:
# 78.2

# %% [markdown]
# ## C

# %% [markdown]
# ## Resaurant Menu Organizer

# %% [markdown]
# ## No.1

# %%
Food_items = ["Banga", "Amala", "Akpu", "Jollof Rice", "Abacha"]

# %%
print(Food_items)
# Out:
# ['Banga', 'Amala', 'Akpu', 'Jollof Rice', 'Abacha']

# %% [markdown]
# ## No.2

# %%
Drinks = ("Desperado", "Skirt", "Habib Yoghurt")

# %%
print(Drinks)
# Out:
# ('Desperado', 'Skirt', 'Habib Yoghurt')

# %% [markdown]
# ## No.3

# %%
Food_items_D = {"Banga":8000, "Amala":4000, "Akpu":500, "Jollof Rice":7500, "Abacha":2500}

# %%
Dict_values = Food_items_D.values()

# %%
print(Dict_values)
# Out:
# dict_values([8000, 4000, 500, 7500, 2500])

# %% [markdown]
# ## No.4

# %%
print(Food_items[2])
# Out:
# Akpu

# %% [markdown]
# ## No.5

# %%
print(Drinks[0])
# Out:
# Desperado

# %% [markdown]
# ## No.6

# %%
least_expensive_price = min(Food_items_D.values())

# %%
print(least_expensive_price)
# Out:
# 500

# %% [markdown]
# ## NO.7

# %%
Food_items.append("Loaded Fries")


Food_items.append("Afang")

# %%
print(Food_items)
# Out:
# ['Banga', 'Amala', 'Akpu', 'Jollof Rice', 'Abacha', 'Loaded Fries', 'Afang']

# %% [markdown]
# ## No.8

# %%
Food_items_D = {"Banga":8000, "Amala":4000, "Akpu":500, "Jollof Rice":7500, "Abacha":2500}

# %%
# helps you to see object of the dictionary's values

Dict_values = Food_items_D.values()

# %%
print(Dict_values)
# Out:
# dict_values([8000, 4000, 500, 7500, 2500])

# %%
average_food_price = sum(Dict_values) / len(Dict_values)

# %%
print(average_food_price)
# Out:
# 4500.0

# %%
print(f"The average food price is: {average_food_price}")
# Out:
# The average food price is: 4500.0

# %% [markdown]
# ## No.9

# %%
Food_items_D = {"Banga":8000, "Amala":4000, "Akpu":500, "Jollof Rice":7500, "Abacha":2500}

# %%
Food_items_D["Loaded Fries"] = 6400

Food_items_D["Afang"] = 5500

# %%
print(Food_items_D)
# Out:
# {'Banga': 8000, 'Amala': 4000, 'Akpu': 500, 'Jollof Rice': 7500, 'Abacha': 2500, 'Loaded Fries': 6400, 'Afang': 5500}

# %% [markdown]
# ## NO.1 SECTION 2

# %%
Scores = ["82, 95, 43, 70, 80, 50, 30, 68, 90"]

# %%
Student_Grade = input("Scores: ")
# Out:
# Scores:  82, 95, 43, 70, 80, 50, 30, 68, 90

# %%
Student_Grade = int(input("Enter your scores: "))
# Out:
# Enter your scores:  82, 95, 43, 70, 80, 50, 30, 68, 90
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 Student_Grade = int(input("Enter your scores: "))
#
# ValueError: invalid literal for int() with base 10: '82, 95, 43, 70, 80, 50, 30, 68, 90'
